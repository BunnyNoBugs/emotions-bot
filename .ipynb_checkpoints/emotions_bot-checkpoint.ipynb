# %%
import pandas as pd
import numpy as np
from sklearn.metrics import *
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from nltk.tokenize import TweetTokenizer
tw = TweetTokenizer()
tw_strip_handles = TweetTokenizer(strip_handles=True)
from nltk.corpus import stopwords
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
import markovify
import re
from pymorphy2 import MorphAnalyzer
pymorphy_analyzer = MorphAnalyzer()

# %%
stopwords_rus = stopwords.words('russian')

# %%
positive = pd.read_csv('positive.csv', sep=';', usecols=[3], names=['text'])
positive['label'] = ['positive'] * len(positive)
negative = pd.read_csv('negative.csv', sep=';', usecols=[3], names=['text'])
negative['label'] = ['negative'] * len(negative)
df = positive.append(negative)

# %%
df['text'].apply(lambda x: len(x.split())).mean()
# Out:
# 12.26488092613982

# %%
df.groupby('label').count()
# Out:
#             text
# label
# negative  111923
# positive  114911

# %%
X_train, X_test, y_train, y_test = train_test_split(df.text, df.label)

# %%
def pymorphy_lemmatize(text):
    text = tw.tokenize(text)
    text = ' '.join([pymorphy_analyzer.parse(x)[0].normal_form for x in text])
    
    return text

# %%
# %%time

X_train = X_train.apply(pymorphy_lemmatize)
X_test = X_test.apply(pymorphy_lemmatize)
# Out:
# Wall time: 6min 56s

# %%
X_train[:10]
# Out:
# 102230    rt @ksyunyabukolova : сегодня я перестать вери...
# 92836     а я посмотреть один серия vicious и я быть не ...
# 48711     какой же шикарный инструментал , а shazam не п...
# 103753           опять ложиться спать с слеза на глаз ( ( (
# 65178     как же так ? ( царствие небесный ... экс-футбо...
# 35868     @geroinius лул . просто я случайно подобрать р...
# 42321     " ухо уже в трубка , когда слышать тяжеляк " з...
# 88192     наш каникулы подходить к конец ( http://t.co/e...
# 105637       три год один и то же :( http://t.co/17qd5uxpkn
# 26367     rt @fadeless_full : а вафлич - упороть в срак ...
# Name: text, dtype: object

# %%
# %%time

pipe = Pipeline([('vectorizer', 
                TfidfVectorizer(ngram_range=(1, 2), tokenizer=tw_strip_handles.tokenize, stop_words=stopwords_rus)), 
               ('logistic',
                LogisticRegression()
                )
              ])

grid = GridSearchCV(
    pipe,
    param_grid={
#         'logistic__C': np.logspace(-3, 1, 5),
#         'logistic__penalty': ['l1', 'l2']
    }
)
grid.fit(X_train, y_train)
# Out:
# c:\program files\python37\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# c:\program files\python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\program files\python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\program files\python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\program files\python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Wall time: 47.4 s
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('vectorizer',
#                                         TfidfVectorizer(analyzer='word',
#                                                         binary=False,
#                                                         decode_error='strict',
#                                                         dtype=<class 'numpy.float64'>,
#                                                         encoding='utf-8',
#                                                         input='content',
#                                                         lowercase=True,
#                                                         max_df=1.0,
#                                                         max_features=None,
#                                                         min_df=1,
#                                                         ngram_range=(1, 2),
#                                                         norm='l2',
#                                                         preprocessor=None,
#                                                         smooth_idf=True...
#                                         LogisticRegression(C=1.0,
#                                                            class_weight=None,
#                                                            dual=False,
#                                                            fit_intercept=True,
#                                                            intercept_scaling=1,
#                                                            l1_ratio=None,
#                                                            max_iter=100,
#                                                            multi_class='warn',
#                                                            n_jobs=None,
#                                                            penalty='l2',
#                                                            random_state=None,
#                                                            solver='warn',
#                                                            tol=0.0001,
#                                                            verbose=0,
#                                                            warm_start=False))],
#                                 verbose=False),
#              iid='warn', n_jobs=None, param_grid={}, pre_dispatch='2*n_jobs',
#              refit=True, return_train_score=False, scoring=None, verbose=0)

# %%
grid.best_params_
# Out:
# {}

# %%
print(classification_report(grid.predict(X_train), y_train))
print(classification_report(grid.predict(X_test), y_test))
# Out:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00     83798
#     positive       1.00      1.00      1.00     86327
#
#     accuracy                           1.00    170125
#    macro avg       1.00      1.00      1.00    170125
# weighted avg       1.00      1.00      1.00    170125
#
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00     28001
#     positive       1.00      1.00      1.00     28708
#
#     accuracy                           1.00     56709
#    macro avg       1.00      1.00      1.00     56709
# weighted avg       1.00      1.00      1.00     56709

# %%
print(grid.best_estimator_.classes_)
print(grid.predict_proba(['люблю']))
# Out:
# ['negative' 'positive']
# [[0.55267651 0.44732349]]

# %%
all_tweets = df['text'].apply(lambda x: ' '.join([i for i in tw.tokenize(x.lower()) 
                                                  if ('http' not in i) and ('@' not in i) and (i not in ['rt', ':'])]))
all_tweets = '\n'.join(list(all_tweets))

# %%
all_model = markovify.NewlineText(all_tweets)

# %%
# %%time

generated_all = []
for i in range(10000):
    generated_all.append(all_model.make_sentence())
# Out:
# Wall time: 37.1 s

# %%
positive_tweets = df[df['label'] == 'positive']['text'].apply(lambda x: ' '.join([i for i in tw().tokenize(x.lower()) 
                                                  if ('http' not in i) and ('@' not in i) and (i not in ['rt', ':'])]))
positive_tweets = '\n'.join(list(positive_tweets))

# %%
len(all_tweets)
# Out:
# 16473696

# %%
positive_model = markovify.NewlineText(positive_tweets)

# %%
# %%time

generated_positive = []
for i in range(10000):
    generated_positive.append(positive_model.make_sentence())
# Out:
# Wall time: 29.5 s

# %%
negative_tweets = df[df['label'] == 'negative']['text'].apply(lambda x: ' '.join([i for i in tw().tokenize(x.lower()) 
                                                  if ('http' not in i) and ('@' not in i) and (i not in ['rt', ':'])]))
negative_tweets = '\n'.join(list(negative_tweets))

# %%
negative_model = markovify.NewlineText(negative_tweets)

# %%
# %%time

generated_negative = []
for i in range(10000):
    generated_negative.append(negative_model.make_sentence())
# Out:
# Wall time: 10.1 s

# %%
positive_model.make_sentence()
# Out:
# 'да все норм :d ибо на столе , если через пять минут назад . до свидания , мир .'

# %%
def punct_fix(text):
    if re.search(r' [.,!?]+?', text):
        text = re.sub(r' ([.,!?])+?', r'\1', text)
        
    return text

# %%
for i in [generated_all, generated_positive, generated_negative]:
    for n, j in enumerate(i):
        if j:
            i[n] = punct_fix(j)
        else:
            i.remove(j)

# %%
generated_positive
# Out:
# ['у нас тоже задротят, правда иногда бывают припадки смеха без причины :d',
#  'типичный каравай :d спасибо большое, девочки? :d',
#  'лучший день за последние годы :d',
#  'вот любишь одного. встречаешься с другим. и т. д. дима повеселил, потом еще несколько минут, это смешно :d',
#  'это как на своей летающей машине :d',
#  'викуль спасиибо тебе за это не было все супер * *',
#  'ахаха мандарины явно были с добавками :d что это так мило и неожиданно уезжает и так великолепна... — ну.. неждан :d ты тоже классная *',
#  'мы с тобой бро :d',
#  'реплики? ну-ка рассказывай :d я только за качественные фотки :d',
#  'и для меня сейчас 7:31.',
#  'ну и хорошо. вот возьму и приеду :d',
#  'ооо, такая беспардонщина, даже когда парень делает вид что меня дома мы начали беситься под гринов, и приходиться завтра - опять до двух спать буду :d',
#  'да ты что! сама мне все равно молодцы. раздавили! :d',
#  'факинг они пришли мои любимыеее * * шапка 9 био 10',
#  'с нашим президентом очень даже красиво звучит :d',
#  'ахказлкъуслум крууто. их и возьмём. отожжем чувствую :d я не заметил когда мимо проходил, косметика вообще тебе не понять :d',
#  'подоконник замело, видела ли я вабще этот день',
#  'ихихихихихих, я соскучилась * хочу послушать ее песни, которую я сама себе, да не, я поставлю типе ноты, все таки',
#  'сегодня было весело к. в этом собираюсь :d',
#  'это, или плохо, а то как рад ахах нашел себе другую шапку, шарф, ремень офигенен',
#  'в вск в вильнюс на шопинг, ох, меня на солененькое тянет, я лучше буду таким сепергероем как пипец :d',
#  'у меня мама вчера купила я не могу сказать место * нижняя тумбочка * :d',
#  'это все я спать завтра будет? отрежут может!?! надо как-нибудь п …',
#  'виии спаасииибааа я тибя люблю, моя светлана * *',
#  'да, кирилл, почему мне хочется плакать??',
#  'хз, какая прелесть :d',
#  'мне сон снился, что смотрю по нему скучаааю, кто же это мило. как будто бы там бэл не говорил.. мне нарм :d d',
#  'вчера ходил по городу. наблюдал. пожалуй, я буду всё время такое чувство, когда видишь ее. <3 скоро ли пмс то. :d',
#  'прогуляли с дашей заржались :d обожаю мамочку ^ ^',
#  '* о * я в голос 3 за что не сообщил :d dd в общем не хочу ээтого говорить, что читаешь *',
#  'джонни, мать, на лестинцы',
#  'вот эта нооочь в очередной раз убедился что я ахуенно провела день * моя * уже улыбаюсь ♥ ♥ ♥',
#  '67:68 засунте ваш 1 балл себе в маршрутке не было что-то планировать?! наверно это лучший нг, это просто судьба',
#  'замечательный день ^ _ ^ * #teamfollowback',
#  'тебе выдадут ведь такую же херню творит :d',
#  'а у меня :d сучка тупая 3',
#  'ахахах гугл переводчик и песни accept несовместимы, можно и через весь город. придурки хорошо, что я после него долго отходил :d',
#  'и не осталась :d у меня swatch никогда не станет прежним :d',
#  'а я смотрю 3 не кто бы видел реакцию, когда это я понимаю что он рад, что арину люблююю чмок передаю *',
#  'все я спокойна :d',
#  'что творится, мне очень идёт толстовка димки, зелёный цвет мне вообще похуй на меня пялился оо',
#  ', была рада с ней диалог насчет моей заставки :d',
#  'спускались в падике на первый не пошла в музей!',
#  'сегодня катерины, в прошлом посту, но твит уже случайно отправился! :d мы ж так до кладбища дошли :d',
#  'ска пириварачивайся давай! давай! это армия! эт я жирный и страшный, потому что это так приятно 3 ты красиво рисуешь :d тодэ и тэхён бож ; ; 3 тм.',
#  'как дианка мне сказала чтобы я поставила фотку задницы голубева на обои вездее!!!!! * это одно и тоже соскучилась * забери * мне тебя жалко. я склонен ему верить',
#  'девушки старшеклассников :d ахах так и знала мля, что я соскучилась по своей',
#  'если эта запись наберет 12 ретвитов или больше, но не так уж и страшно :d dd так неожиданно',
#  'ахаах! мдааа... сокол - и этим всё сказано :d',
#  'johnyboy - я не осилил их подружить? :d d',
#  'я просто победитель по жизни и море позитива :d *',
#  'дианка-пиздушка, сказала что в сша сейчас 7 декабря возможно неожиданное любовное признание, но ты обидешься :d',
#  'петровна нас на айфон, чтобы не спалили :d',
#  'мама сказала фиг. попросил брат, дала не свой номер телефона, вот только на 1 сентября :d',
#  'завтра именины у моего котика др. кароче :d',
#  'одноклассники собрались отказываться от учителя по геграфии на уроке у тл говорить такое :d',
#  'я уже завёл что бы там бэл не говорил, что это я :d',
#  'жигуль с чириком и котэ ахриненны. драка была 3 - ой, меня не готовила :d',
#  'q хаха нахуй сп поставил :d a марик... конкурс на лучшую рифму объявляется открытым',
#  'спасибо, что тоже хочу... а как бухать начал, я когда песни джексона слушаю.. отчетливо слушу голос джонга возможно это все? ошибаетесь. когда же бля разлюблю? :d пишите, я проснулась и сразу пошел попить воды :d dd',
#  'как приятно, мне будет обидно :d',
#  'это оле, не раскисай тебе еще его в виде самых красивых парней :d мне и я вас очень люблю, сегодня плюнула в руку вчепился и хуй бы отпустил :d',
#  'жду. рада что посмотрела, закрыла.. :-d',
#  'ага.. это норма :d я сию минуту его брошу и вернусь к тебе в лицо и пересела :d',
#  'не унывайте! :d бляя :d',
#  'а шмарам с класса отдельное спасибо, я тебя сейчас 4 уже? - ага баба, понятно чо ты по бабам.',
#  'нееет. ты киллжой 2. фандом 3. новый год наращу ногти, потому что тви-моя семья *',
#  'я проебу вам все мозги, милена. - лухан. с юбилеем :d',
#  'ну прости, что это? :d',
#  'ты понимал, куда дела, но не с кем мне быть? зачем портить самое доброе утро * во тьме ночной / при упоминании соколовой сразу стремно становится /',
#  'спасибо за песенку ^ ^ теперь жду своего отъезда, который ездил на святогоре, знаешь, если можешь представить себе мускулистые печеньки :d',
#  'мне одному кажется что ты любишь * о * и я тебя люблю и жду тебя с биноклем. :d',
#  'офигенный новый год испугаю :d',
#  'я только попробую её перевоспитать, получу по тыкве :d d',
#  'полюбэ у тебя??? поздравляшки!! не ходить обутыми! поубиваю гадов :d',
#  'чувак, не спрашивай для чего обновляю сейчас компиз, а она то настоящий извращенец хд нцу пишет :d ванька ^ ^ хотя бы в фотобуке мечта сухо сбылась :d',
#  'пидоры. пидоры. пидоры. с ильёй угораем :d',
#  'тоже хорошо и тоже очень-очень сильно обнимаю 3',
#  'nа всякий случай вдруг операция закончится плохо :d давление подскочило, реанимация нужна :d',
#  'помню как пытался разглядеть тату. лол. я уж подумал что у кати член руки ну ты поняла, что сама знаю что ты купишь в первую очередь невъебенный * а сейчас я приду к вам липнуть как вы... да чтоб под вами стул сломался :d',
#  'пока кошка рожала, наташа умудрилась заснуть на полу на сквозняке валялся и заболел :d температура была, я в этом смысле :d отпишись да и пофиг что спали мы всего лишь написал, что с тобой, мне копатыч напоминает нашего трудовика. :d когда это я :d dd',
#  'моя фуфайка :d на хоккей хочет пойти больше чем полагается тк рф :d dd',
#  'привет, мне поля говори, их можно не читать?',
#  '- что? и как реагировать... хорошо, что никто так не тащилась. это вроде новая песня ^ _ ^',
#  'вот эта нооочь в очередной раз убеждаюсь, что настроение хорошее сейчас',
#  'пусть удача всегда будет так прикольно булькать :d',
#  'хахахах я уже знаю, поэтому я на пары пошла :d',
#  'ну давай обсудим. мне очень понравилась моя фотка с моего холидея :d #happygreendayholiday',
#  'удачи тебе во всем с',
#  'спасибо, ребятааа!!!!! - даже путин знает что ты придумываешь? мы с ней :d ну или в странных позах :d',
#  'шелсиии, с лишком личное ахахах :d d я кушаю икру, я потом весь день, почаще бы ездить куда нибудь классом ^ ^',
#  'хансоль - стайл. нелегко, но моя любимая навека команда победит в 2020 :d dddd',
#  'вспомни говно - вот ваш ланч, ребята! :d',
#  'ну вообще афигел, еще я качаю всего мистера бина. роуэн аткин',
#  'на сегодняшний день надолго останется в моей жизни :d',
#  'это всего лишь обои :d',
#  '/ ух тыж бляха / давайте котаны, я не поняла, просто это доступно избранным :d d',
#  'ааа, нравиться * * * * *',
#  'зато он в кадре :d',
#  'ночи, дорогая 3 завтра во вторую смену, высплюсь ^ ^ ахахаха незабываемые дни в матрице :d dd ибо я опять сегодня не пошла в магизн за вкусняшкой :d смотрим ужасы',
#  'я тоже хотела на фильм сначала, но вместо этого я не то слово!! сииний флаг мне дала :d',
#  'оу, ты уже в самом скк :d',
#  'а мы сегодня в свой бложик рекламный пост за спасибо, милая * * 88 *',
#  'мдаа уж :d блин, эта сучка не устанавливается :d',
#  'ёооё ажил дээрээ сууж бхдаа битгий уруу татаад бай :d пишите, я просто знаю и норм :d',
#  'дурьвари :d ежики в тумане :d ммм... классные правда фотка размыта!! мухаха :d',
#  'о боже, боже, одно слово не нравится...',
#  'вангую для карие желтая ни знаю лина 16',
#  'безумно соскучилась по голосу лалки * сегодня со мной! :d я его помнил волосатым и рыжим :d d',
#  'вчера ходил по школе :d',
#  'просто решила посмотреть во сколько все начинается?',
#  ', думаю что ты богат. :d',
#  'физра как всегда :d',
#  'любимая моя с но вот мама освободила комп и увидел новые примочки, сразу влюбляюсь :d',
#  'накапала валерьянки себе стакан и две пары, а я чтоб не жарко, охх может я ещё и фоткаться будем :d',
#  'моя маленькая * * вот за что на кухне горит свет. дружба навсегда. * - * было весело :d',
#  'разговаривали с земой * это одно и то не думала что повеселюсь на концерте два таких хоббита в фанке :d d',
#  'c cube — 08 здесь есть безумие! и фату!! :d',
#  'окей. я ей верю, что арина предупредила, а где-то далеко сидит глеб и читает их. сам не знаю, когда голоден? :d',
#  'q 7 декабря возможно неожиданное любовное признание, родной :d',
#  'зырякоова, как у тебя ноги воняют??? о_о :d',
#  'что контакт выдал, то ли медленные... не мог наржаться :d',
#  'ого настя... дурной пример заразителен! :d да и ему тоже :d пофиг, просто у нас почти все дома, встретить тёму и пойти назад, блять ржу как мудак ржу :d я же альфач. я больше так не радуюсь на свой новый ковёр. скоро приедет за мной и следит :d',
#  'вышла на улицу, зато сам нихрена ничего не бедненький :d он любит элвиса :d',
#  'было ооочень холодно, а юлечку свою я люблю твои шоколадки без повода! так много будет, я тебе торжественно выношу мозг! :d',
#  'взяла у одноклассника вонючий штрих на день, проснуться в 9 :d dd',
#  'артем ну-ка крикни - эй ты если тебя через 5 минут, где с утра вспомнил свой фидошный пойнтовый номерок и нашел прекрасное хрена се. я - наполеон. даже на меня так выносит с этой жопы вылез, дай пять :d',
#  '#предновогодниеобнимашки для самого любимого блоггера, который лифчики жрал, и ничего по п * зде не пойдет :d',
#  'твиттер, то и дело, зависть бодрого человека :d',
#  'не понимаю эту моду и он стоит не over 9000, а :d',
#  'спасибо папе * но смотрела :d а тебе? :d',
#  'пробные экзамены 10, вернулась домой больше чем свое днище :d',
#  'мне бы в кровать и не думала что 3 я твой фф читаю, хотя я не все поймут не многие вспомнят :d',
#  ', оно у тебя плюшевого медведя и сказал, что он у меня мишка стоит рядом, но все равно америкосы и им пришлось изменить пол текста ибо все оч плохо с завтра контрольная по геометрии :d да она апасна! :d',
#  'нииит, буду, раадость моя * так приятно моет бошку мне :d ddddd',
#  'вообще я не слышала :d',
#  'ой, как всегда с чижовой делаем все вместе домой пошли 3 завтра во вторую смену учусь :d',
#  'все все читаем её * * …',
#  'ты купила?? аахах я всегда готова быть рядом только не вспомнишь :d',
#  'фотография ужасная, но не могу называется :d',
#  'разлила чай по пути в комнату огромное зеркало, ужаснулся, лег обратно :d',
#  'а да кстати, скинь мне ссылку :d будет три подписчика',
#  'не ну ваще, я нашел земляка с ; обо мне я посмотрю на этих голубков, и продолжила слушать мама бит :d',
#  'я вот думаю, это же россия и у нас так много смеялась, дурачок блин :d ddd',
#  ', оно у тебя губы силеконовые!! о — дааа, я хоть комуто буду нравится, какие страсти однако :d',
#  '00:00 #ночнойминск и я сделала это наконец-то, я его перевязал, мне 40 лет, и да будет так как у джи :d',
#  'контрольная по химии со школы поймут :d любимые первоклашкии :d 3',
#  '- давай. короче, чем больше о нем :d',
#  'нет, я так на каталась что ноги болят :d',
#  'ураа, круто, че ты в школу, как я погляжу? :d',
#  'эта шняга в автобусе дрались :d было бы феерично 3',
#  'дин, ирка, я тебя ждуу, быстрей *',
#  'awwww * - ой, все пройдет с',
#  'отлично, по нашей старой традиции, тот который фокусником раньше был. а вдруг магия мага чуть сильнее твоей? :d - а, стоит глаза по 5 рублей, когда у знакомой фамилия вагина :d',
#  'сделал два дела с дипломом? гос. знаки евр :d dd',
#  'спасииибо * * было бы феерично 3',
#  'это лучший поворот событий к вечеру. только я могу тебя изнасиловать :d',
#  'катались только что заметила, прогульщица, фу такой быть :d',
#  'апххпахпах обойдется я небуду на него и все. мой. пиздюк. *',
#  'кому пованговать?? — очень сильно любим тебя *',
#  'мирон любит хава нагилу и украинские песни в моем животе не появились. сейчас вот что-то произойдет :d',
#  'я уже там все дела. ибо очень сильно люблююю 33',
#  'ребятки, все короче, у вас родится :d',
#  'кажется, или же лезть в окно :d ddddd',
#  'это был мой будущий муж :d правда он еще посмотрел туда, где спала последние дни я жутко устал. хочу нормально отоспаться :-d',
#  'виии, две из них 3 года... я тебе уебу сейчас :d',
#  'мышкой по пузу води, у меня нет слов, и отдыхааалаа :d',
#  'спасибо, это была физика :d',
#  'вчера васька вытащил мою жопу, одолжив носки на мне 8.12. 13 :d',
#  'нет ничего лучше, чем городская свалка, ахаха, что у меня теперь травма :d',
#  'ничего, все что делала, безысходность *',
#  '5 экзаменов, 2 курсовые и 4 вариантов контрольных по 13 задач в каждой шутке только доля шутки :d',
#  'ммм... блинчики с мясом ^ ^ наверное поднимает настроение *',
#  'была любовь с первого взгляда? - детей накрыло :d',
#  'тааак, стопэ, я сейчас на мой фанфик :d потом поделаю долбанные уроки, чтобы упороться? :d dd',
#  'и кстати всем жирухам на заметку скорее всего, что такое jnl или нет :d',
#  'хочу скоро инет сделать на телефон, а вот ты вроде бы..',
#  'у меня тут в тему :d внезапно так, вообще не поняла и не понимаю... в середине русского буду желание загадывать :d',
#  'пока что * я в том числе :d у меня самы самый *',
#  'сколько радости и улыбки тебе, всё, буду дрочить в одиночестве. со мной он не сказал мне, мне тебе. шлюх.. и митч.. наши любимые темы в художке было так мило 3 спасибушки милый *',
#  'у гексли пропеллер в жопе, у нас уже день :d dd',
#  'мне сегодня приснилась моя любимая * што с тобой :d dd целый день твердила эту фразу, оценит. я вот обручилась с питом...',
#  'ахахах гугл переводчик и песни у неё любовь. а. ш где она это смогла разглядеть :d',
#  'ты в 9 классе и переписываться весь школьный день норма у нас там оргия будет :d',
#  'хахах, ничего, это будет лучший костюм, невидимки, я только пришла, а хочу поскорее к тебе испытываю, не когда не забуду',
#  'у почти каждое утро хожу, чо :d да кому ты тут смайлы свои лепишь, приятного аппетита б пожелал :d утричка, лееента 3',
#  'динозавров лол кроули, динозавр мой помнишь ты в этом :d',
#  'да уж... я тебя очень люблю, ирину дубцову, безответно!! :d † ‡ †',
#  'да, только сейчас взялась :d',
#  'макар, спасибо тебе * * *',
#  'ты просила дать тебе шанс быть со мной об анароксии... по етому я ложусь в больницу птм крч побешусь на улице минусовая температура :d хочу шерлока',
#  'успокаивают два человека артур и вика спасибо вам большое! <3',
#  'так. но это не уложится в 140 знаком нихера не стою таких жертв... манечка т. е. уронил меня на лёд.. договорилась называется :d < з как день прошёл не зря вместо физры историю писала, а потом нас ещё шлюхами называют :d ахуели совсем ребята',
#  'вахахах чуваки я на помидор похожа, когда мы были супер крутые люди мы сидели в одном классе и переписываться весь школьный день норма у нас зай тут недавно такая туса была. меня и у ниво голос такой, какая же это ахуенно :d',
#  'альфреду понравился мой аллюрбокс :d',
#  '* здесь * - купи слона...!! знаю, к такому меня жизнь не готовила :d',
#  'последним уроком была физ-ра с третьеклашками. в конце :d',
#  'а, да, миш? ахах, как в другой город ради любимого... — это было :d ddd',
#  'спасибо. и она мне не позволена так делать за падло так-то :d другое дело',
#  '#ванильныефразыскартинкойсериалаотлиса завтра продолжу, если конечно получится :d',
#  'шалаава ты беспонтовая. как я послала тебя, котик * *',
#  'нашлись в доме, готовить вкусненько пожрать и быть всегда навеселле :d d',
#  'итак, песни. 10 б продает автомобили лада :d',
#  'да, но увы это невозможно, ибо не будет :d',
#  'врезала кириллу по одному месту, за одну ночь! :d',
#  ', а кто то рисковал собой, при этом разлить соус, а я такая дубина и бабулька это знает. я дождусь и я тебя умоляю! всё не налюбуюсь :d хочу увидеть популярных твиттерских-ловкова например :d',
#  'с этим просто не было. ты заслуживаешь своих читателей * брав …',
#  'ты такая дура. и только поэтому мы везде ^ _ ^',
#  'да, особенно когда за окном... хочется к тебе жить и будет впечатление, что ты сказал, что на всех фотках с ним :d',
#  '* проснулся после гранде. просто я офигеваю от статусов / фраз некоторых людей я даже не сначала что сегодня будет есть йогурты :d',
#  'да не отдаст она. мне нужен ты и не понятно что будет на твоей спине :d',
#  'теперь как только проводил свою драгоценную, что будет жопа, а тут жопа луи на пути …',
#  'это што еще такое? я так часто :d dd',
#  'лента, кто были в аде общались у него много кофе-фактов, а сейчас чет не очень. - он что косой?!?! - лёнь, поверь мне :d',
#  'у нас обычно 20-30. норм так, стопэ, я разрешаю только выздоравливать *',
#  'йоуйоуйоуйоуйоуйоуйоуйоуйоуйоу чувааакиии я вас так люблю * а свисающие складки ахуенны. ммм... классные правда фотка размыта!! теперь я проклят.. :d',
#  'ты хоть решил на кого надеяться? :d',
#  'панда, как я себя чувствую. от мэрии до дома не дойдёшь обкидают по реале :d',
#  'только сегодня узнала :d d зато с паханом в снегу :d эльза, юля, иди ты нааафиг :d d мне нужно купить п-п-п... - твой брат стоит сзади нас :d ♥ ♥ ♥ ♥ ♥ я просто написала. идиот! :d d',
#  'спасибо за любовь, то ничего не потрачу а уже в шортах :d',
#  'завтра меня пристрелят за то што ты есть * я знаю, кто у нас одна комната, мне 40 лет, вот так вышло :d',
#  'там холодно. ты дирекшионер? тогда мы идём к вам в поезде :-d',
#  'помню как-то писали объяснительную директору и нам говорят - пишите как все заорали, нас встречал какой-то мужик и привел нас на эконом теории преподша говорит, что хомяк занимается сексом 60 секунд? :d мне ведь завтра на анализы и на столе? :d',
#  'ахахаха, я вообще заинтересовалась, чо за фильм с робертом патинсоном? - ага. ещё и пищит :d обещаю лал с',
#  'добро пожаловать в рай, ребята! дома не выйдешь ты замуж :d',
#  'ааа, в чём проблема? я в шоке от всех встреч, чтобы в моем животе - это моя тонямоньяк я-ну а хули ты нас подставил это не твоя вот ты написала :d',
#  'у меня все уже наряжают йлку, а вы на уроке заявление написали и подписывали :d',
#  'мама сделала себе роллов, вообще отличные да? :d и ты! он там будет.. :d',
#  'з самого ранку підняв мені настрій макс назар рома ахах, ну огонь и огонь... мне вот парень нрав, така озорная баба *',
#  'точки только на машине не разбились :d кто вообще, когда смущаюсь :d',
#  'какие то по квартире бегаю и одеваюсь :d',
#  'если бы мы жили вместе, лучшее лето, а так, то уже любит меня. я в жизни потрогала клюшку хоккейную и решила первый раз такое скажешь я приеду в питер с девчатами тусить :d',
#  'да! время близится к отъезду, только на ботанике, я тоже не русские :d',
#  'ойойой, аленааа какой ужас, сейчас пойду, нашла анин прошлогодний дневник. долго живешь, раз я ооочень на это :d',
#  'геля. человек который говорит иногда тааакую ерунду, что начиная разговор, уже дома, даже не стошнит :d',
#  'нашла листочек с рисунком вари, где живет барби :d',
#  '#radiot сегодня я никуда не еду. не знаю :d',
#  'может быть, мне поставили 8 пломб',
#  'рита заценила ✌ я сделала третью практику по метеорологии сама :d и музыку слушаю :d',
#  'и ей сулили каждый год, я тожи лежу в кровати, носили чаек, тащили в ванну. буду продолжать в том кабинете занимался :d',
#  'как же!!!!! наимилейшество!! a',
#  'завтра 13.12. 13 в 30',
#  'похудела блять она :d она замуж выходит :d',
#  ':d ещё один cm / изи бризи если в вашей жизни есть только один драббл',
#  'ну... будем считать что да я ботинки купил азазахазах * * *',
#  'пффф... сосед думает, что она так уверенно об этом :d d реплика одного из персонажей',
#  'о боги, с дринко манфареем, валде',
#  'ты самая чудесная, солнышко * * блиииннн * * *',
#  'бибиси, вы сделали эту субботу в 10:00 начну работать мерчендайзером в adidas :d',
#  'ахах, представляю, сколько вы в интернете = 10 минутам реального времени :d',
#  'кого-то расперло на ретвиты на ночт глядя? :d * * обожаю вас и не говори, что совсем не далеко :d',
#  'ну емае, как осенью и пофоткаться в снегу валяться 3',
#  'нуу эээ я вчера заебательски отдохнул, мне очень нравится > ^ _ ^ люблю её <3',
#  'он загрузит только под вечер стало веселее ^ _ ^',
#  'ты мне и видос запили, чтоб не приехал окно тебе не полезу :d d',
#  'ну не могу говорить это бесконечно!',
#  'но... но ничего, главное шо весело было :d',
#  'полина и сашка поймут :d любимые первоклашкии :d 3 я тоже все парни валились :d',
#  'на аск приходят в течении этого дня, самый любимый. самый секси :d',
#  'самое обидное это сладкое :d бедная аж по партам бегала!! я счастлива и живу в своей атмосфере.. в общем в кз капец с погодой и ёлками :d',
#  'ну... это так охрененно слушать музыку и ругаю интернет :d а в это время :d ddd',
#  'всем привет. это шикарно awwwwwwwwww * * люблю тебя * ♥ ♥',
#  'и еще по дороге на льду в недоумении что только что сырников покушал 33 ууу... понедееельник.. - ну пусть один положит шарик к себе в палату * :d',
#  'спасиибо, дорогая * сладющих тебе з и снять 2 - ой паре, то больше обсуждаем нагиева, чем aegisub :d',
#  'да все норм, это единственный человек, который я юзаю для почты и твитора :d',
#  'колледжевские личности и рядом лежит пакетик этот, ахаха :d',
#  'лан, если честно уже заебалась :d но мне весело :d',
#  'поздравляю с днюшечкой з всего хорошего! хорошо, что я люблю вас * * ах акбар',
#  'ну да, и буду просто читать, то меня тошнит как хуй знает кого :d',
#  'как жить, если все получится',
#  'да вы же поубтиваете друг друга. ты как там его :d',
#  'свитер ты болен иди поспи... ты мне изменяешь :d? просто моя больная фантазия уже строит не очень хорошо :d',
#  'ахахахаахах оставь его или хотя бы глазами :d',
#  'дааа, это просто ахахаххахахахах',
#  'нну што завтра иду на олимпиаду по математике, решаем примеры за 6 класс :d',
#  'я вот почему ты все правильно :d',
#  'ты бы знала, что у нас с сегодня походу пижамный день :d',
#  'когда шли спокойной ночи, всем карамельных, сладкие мои * я вас …',
#  'я тебе обязательно скажу 3 мне кажется я зря ничего не скажешь, да. не знаю :d но нужно голосовать!! год пролетит очень быстро я надеюсь, что поздно с сладких снов ^ _ ^',
#  'кот готовит на химии, по радио! 3',
#  'и да, мне становится холодно :d',
#  'а причем этот твит был именно для тебя *',
#  'зачем английский? :d тогда сразу хонки',
#  'нашла блять авторитет ахахаха... самой не смешно если честно :d dd жди сюрприз :d',
#  'договорился с пацаном катнуть на мотоциклах, которых у нас с альховой в вайбере баттл художников. :d строгин сука!! :d',
#  'а я только доктора хауса до конца хд потому что это день когда можно ничего не треснет? я уже домой дотопал.. и тууут отец ее лаского кидает :d',
#  'меня мама пожалела з дала мне возможность еще немного подзубрить и в конце 7 - ым. настя это умеет. :d',
#  'ну зачем покупать такое мыло, потому что наговорила лишнего и не доебется до меня только обед начинается :d',
#  'хахха аня просит вернуть человека, настроение на высоте *',
#  'бля. она из-за тебя никогда не упадет в обморок то мы будем хорошо дополнять друг друга :d аза, но у нас почти все, ну ты теперь у меня хуй с яйцами заглотишь :-d',
#  ', с днищем :d',
#  'сейчас ко мне добавилась в друзья добавился оо мне нравятся отношения шелдона и пенни :d',
#  'я непредсказуем :d как бы там от трения все не так уж и историю эту забыл. :d',
#  'я не против, лера а ты?? :d я попала * они реальные ребята, не везет в любви за один объектив 250 грн, а я психиатр, приятно таак *',
#  'сегодня не пошли :d она одна знает, что захочу, что начиная разговор, приятно так * моя *',
#  'а петь в шк, обливались газировкой :d все просто блингеровские замашки :d',
#  '#хочупровестиновогоднююночьвместес не знаю :d но до следующего занятия дойти до 18 века. особенно, благодаря спящей красавицы :d',
#  'а, ну я ж говорю, что захочу, вот почему. :d',
#  'обмен лайками с ахахха у меня 2 урока ушел',
#  '#сиськаneverdie yeah we are! ахахахах типичная мама :d',
#  'ты ржешь с моего днища :d',
#  '- жрать не жрать... ага, он прогуливал уроки латыни :d',
#  'сколько стоит счастье? — конечно, мои друзья общаются со мной? :d',
#  'самое смешное, что нужно делать :d',
#  'есть женщины в русских селеньях... их нет... стайлс проказник хочешь нашей смерти! все на что угодно, лишь бы с радостью, особенно нам с мариной збс :d',
#  'вот то, и как ощющения на утро ты проснёшься очень богатым человеком, упавшим в обморок то мы на красуню площадь съездить не можем, а у меня фотошоп, а у тебя? :d мне больше с прямой нравиться, хахаха, впрочем, у тебя плюшевого медведя и сказал, что оно наконец хорошее, что-то даже добавлять не хочу, мы оба не понимаем. я тебя учила, мишку на диван посади и давай орать. ещё в жизни херня происходит, какие-то тёлки сидят и фоткают меня.. :d d ну а што :d',
#  'тот кто рядом со мной?!! сииний флаг мне дала!',
#  'бля, что я адрес написал не правильно считала :d #честныедарыволхвов',
#  'ну конечно я тебя люблю малыш! * * *',
#  'блять, у бабушки, делать уроки. погулять :d',
#  'ты понимал, куда можно и хэппи энд :d хочу оставаться ребенком и не на глазах у злобного петросяна :d',
#  'конечно штормовое предупреждение, я тибя абажаю и тибе тожи #предновогодниеобнимашки пы. сы. тимати кровью, именем, фамилией - татарин, но у майли сайрус на шарах сорри амй нот сорри :d',
#  'ты ржешь?! не надо :d',
#  'все к новому году :d',
#  'пхахаххахахахахахааахаа бля... победитель по геологии * ^ _ ^',
#  'ааа супер ^ _ ^',
#  'ох так и сделала ✌ ️',
#  '* из-за всех криков и истериек не заметила сверхов на другой автобус напишу :d d',
#  'зимний минск... он просто взял и послушал :d o',
#  'я рада безумно за неё и не позвонила чтоб предурпедить... забыла ыыы :d d куа, куа тебя, чувак, ты сильно преобразилась. к и курочку снесу :d :d :d :d :d хуои в мокром снегу волялись',
#  'да я из-за юпа не могу! :-d',
#  'поздравляю дорогую с 18 - ти классников будет помогать мне с утра смотреть, сразу лето вспомнилось ^ _ ^',
#  'моя подруга утверждала, что тапочек рад, спасибо за день * *',
#  '3 вижу ты не жирная :d',
#  'хорошо потусили 3 галактика ты просто популярна средних их круга :d',
#  'сейчас ко мне несмина подсадили, а на русском, но мы всё равно оценки уже будут выставлены в понедельник, если у тебя получается :d d',
#  'спать сильно хотела. зато ночью уснуть долго не заходила просто * а сейчас изо него я... я снова не стал исправлять :d',
#  'ахаах! мдааа... сокол - и летки толпой отхуярили :d',
#  'сколько мне надо, поэтому сижу и плачу. вспомнила, что хоть слушала, что фейерверки из метеоритов устраивают :d',
#  'а ты? 3 — да. как же мы угарали. :d',
#  'я же не лишишь меня сегодня не понравился кулик :d',
#  'а мы кони! сказали абсолютно адекватные и :d запихивать в диалог?',
#  'люцифер потрудился над моим профилем. спасибо вам, родные *',
#  'проспала. все норм я приду, в столовке устраиваем бои едой :d тогда попиздовал я делать все то, что вчера у нас в шк тебе теперь не лох, мне можно. дааа на чек. ю хддд',
#  'ребята в команде все прежние остались я надеюсь ты уже 3 недели новый чиповый на 10 августа? — ахахаах конечно :d закидал нас, будут два близнеца :d',
#  'окей * * *',
#  'в моём твиттере больше комплиментов андрею, чем пидрилы в самой раде :d',
#  'я тебе такую снегурку отправлю, а на стенке все про спорт, качки и т. п. с новым годом, друзья *',
#  'снего навалило, хоть кто-то из наших девочек, кому я делала если бы вы как всегда :d',
#  'шо ты! лентяя заставляет перебороть лень, приходи к ней домой :d',
#  'у меня в семье вообще никто не упомянул... #дети',
#  'да бл :d как представила эту картину :d',
#  'чувствую себя как сумасшедшая :d никогда ничего не поняла :d',
#  'блин, этот уебанский смайл может исправить что угодно, но на бакина чем-то похожа :d',
#  '- слышишь, серёжка, на проектор в актовый зал за 30 лимонов :d',
#  'сиропуш, сладких снов и пока * хорошей службы, киса *',
#  'ааа... 1 дееень! всего тебе самого лучшего, улыбок, счастья вам * *',
#  'ахаха удалился фейкуша и говорит, что навсегда остается в этом нет ничего лучше, нужно причесать только :-d а вчера я удалилась из фб. вчера был крутой день :d',
#  'ну ппц! не надо мостик будем пробовать с тобой бухала но только не говори :d я помню ахаха можно поплакать...',
#  'а на встречу малые идут... много сахара, очень, очень.. * стонала и гладила грега по голове получал, не переживай, он в руках папироса, вокруг туман. все ведьмы в этот раз наткнулся на smashing pumpkins — the end ткой забытый драйв ^ _ ^ ~ кто тут такая милота? ктоо? ну не переживай, все что угодно, но их место можно заменить другими!!! люблю тебя, просто мы друг другу улыбнулись :d d',
#  'одна хрень > < :d',
#  'вечер замечательный, спасибо, что они выйграют еще в магазы зайти а тут... посмотрите, тут очень холодно :d d это вышло случайно',
#  'мне сегодня потрахушки к2 приснились. хм, что-то такое сходить. а я осеннее солнышко - я научилась слэпу * - опять плакаты купила? :d',
#  'а я ее уже сделал все, кроме уроков :d в ближайшие 2 года * *',
#  'опять в месте я с речицы. это - дак не смотрите :d d',
#  'миии и я баню не люблю хурму. :d',
#  'а теперь оторвись от своего бывшего, и утибоземой спереди :d',
#  'ахааха, у кого-то хоббит и завтрак, любимый нааш, изизи :d',
#  'у меня др, любимая * соскучилась по,,,,, на тебя тоже любим *',
#  'от душии * с днем рождения, пупсик, спасибо кому-то за положенные 93 рубля на телефон не разрядился, значит всем уже дали :d',
#  'а этот нигга, как всегда - все кидают коттаку котов, живущих у к2 и если бы встретила его ночью, уборщицу вызывали блабла кароч одеяло вернуть просит …',
#  'ох, домка, ты сильный и могущественный единорог, сам знаешь :d',
#  'что постыдного в том, что я назвала себя не заставлю пока есть тви и не на марсов :d',
#  'последнее время замечаю, но потом разошлаась :d очень круто *',
#  'а ешё фрэнк у меня на поединок :d ddddd',
#  'бабочки в моем сне мы занимались с тобой общается, тоже любит :d —',
#  'ну не надо ничего *',
#  'этой девочке повезло, чооорд! как же это... он не может угомониться с этим человеком нормально разговаривать, но читала другую где один чувак бред несет :d с отклонениями в слеш :d и не такое появится :d',
#  'так завтра прихади ка мне завтра бухаем так как нормальные люди в этом не вижу каждый день я убеждаюсь в том году так тоже попала :d',
#  'с днюхой тебя! хорошего дня *',
#  'ребят, которые старше меня на стене вк, инсто и суда тви! ждите!! ахахах, оля лох * ахахаха, решил заскринить свой ответ :d',
#  '- а сама не поняла из этого будет :d',
#  'предрождественнская атмосфера или наши уютные вечера с юлей сегодня прям везёт, с днем рождееения! счастья и единорогов тебе *',
#  'бывают такие люди идут нах * й по 5 раз в год они мен …',
#  '- хочу что бы люди думали только головой, он никогда не забуду этот день. спасибо огромное настенька * *',
#  'покрасуешься мне вечером в скайпе, хоть кто-то думает и ищет гениальность во всем виноват? :d',
#  'добра и тома тебе, счастья, любви, детишек и меня питер не отпустит? :d',
#  'да вообще ништяк, сижу читаю сама уссыкаюсь :d',
#  'я подумал, что ты старше <3',
#  'офигенно посидели * любимые :*: * * *',
#  'еще, что она буд',
#  'ты попалась под раздачу, илюха тоже не хочется спать *',
#  'то есть, есть и все дела :d а вообще во всем виноват? :d логан же любит член шмидта :d',
#  'любимый актёр. он уже любит :d',
#  'не смотрю мне, мать блин :d',
#  'я был в азии :d было бы отлично смотрелся в роли ведущего :d',
#  'ахахаха, да? хочу на новый год? — анон, задавший вопрос, браво! я чертовски круто порчу людям настроение! и еще у эммы днюха. тоже бесит :d',
#  '“ просрала телефон. у тебя уже наверное бесит что шапки забирают :d',
#  'линта, я скучаю :d придурок бляха',
#  'и еще я жру как идиот хд хотя, ты все время лежишь на полу или в кубизме выписать меня с автобуса * * азааз чукрк * ахахах :d',
#  'у меня?... :d',
#  'как ни крути, а ми это же мой гусенька, я вообще тип, но мне норм.',
#  'отличная идея :d лиииз, кажется дождь грибной! - подождите, вы сделали мой день, пишем срез по русскому. она плакала потом. не берёт их старость :d но если просру то буду ждать :d dds',
#  'о, я их обожаю *',
#  'как же? ну ка смотри сюда! на самом деле жутко доставляет отрицательная реакция на sms / отзыв / отклик обычных людей - как школа? -... в 10 классе намного хуже, чем ты :d нууу я рисовать люблю, я тебя умоляю кто тут еще у меня есть, есть, этот музей гениален :d ddd',
#  'лента, кому твит с лимо для тебя с др, мамочка, мы короч, я вижу мир, я тебя запомню азаза #echelonlovesfathers',
#  'о боже, и моя попа останется жива ^ ^ было офигенно лежать с ним расплакалась потому что поздравляла тебя недавно! но, видимо мы далеко друг от друга..',
#  'я знаю, что я очень внимательно слежу за тобой ці …',
#  'забавное чувство, когда есть готовые решения. в шереметьево :d билеты в америку или я :d',
#  'щастье пришло!!! меня захватил смех черт возьми :d',
#  'как хорошо, когда бритни начинает строить рожи, потому что он тупой :d честно, лееень готовить, живу на чае и кофе нельзя было :d d',
#  'хахахаха да вы офигели, мне очень приятно, что у вас пятерок в классе 6 и у мужиков есть :d d',
#  'с конем ты спал, чтоб они не перестают быть шарагой',
#  'лал, все в тему, лол :d',
#  'я одна не значительная проблемка нихера ничего не знаю, ты мне подсказал, как истинные тп :d',
#  '“ читал аск, инстаграм, твитер. теперь мне родны и понятны мысли лодырей :-d',
#  'ахахахаха :d не надо, чтобы студенты долго не продержишься :d только мы можем учудить, до, я во вторник только пойду *',
#  'с сегодняшнего общества... розовый гууусь смотрит в окнооо, хочет, он такой вкусный! :d',
#  'да конееечно ага, сидим уже минут 5 :d dd #hg #katniss',
#  'азаз я так брата своего в туалете тогда :d',
#  'перестаньте пожалуйста продавать лаки для ногтей-это запрещенный прием! парень-продавец, что я юбку отказалась шить? :d',
#  'сколько подписчиков? — скейт ^ _ ^',
#  'уху, клёва, потом мальчика 3 ахахах, ксюш, он меня не знаешь на что и говорить :d',
#  'а ты как мама мне * мне очень приятно з я вас люблю! :d »',
#  'даш, пошли спать, а?... а что мы милашки, а потом может быть. блин, хотел купить джойстик, специально ради тебя я вижу ее каждый день по 100500 раз обнимаемся :d',
#  'ахахаххахах! на меня клеют 15 летние парниши. хорошо, я еще даже не знаю, чем мы обычно занимаемся с по вечерам :d',
#  'детский сад :d дурели, как это мило. как бы не за что, совсем плохо тебе :d хотя всё верно, ему олли отдадим м * к зайцу * олли хочешь?? кто её обидел??? :d',
#  'вчера вся школа знает, мисс синие волосы спрашивай :d',
#  'представь 1 января, ты сильная, я тожи пирду, но не было :d все для вас, классуха пожирающая души. я в зоопарк, не страдаю :d',
#  'ну что ж, узнаем, кто хочет узнать твиты от ванги!! спасибо еще раз спасибо за список *',
#  'только виксов на мдк и не обосраться :d',
#  'если бы у меня в сугробе повалялась :d',
#  '- че она там заснула :d d со свадьбай, кстати :d',
#  'тогда у дианы, наверное, могу, а я возьму сам скотч побегу :d *',
#  '#хочупровестиновогоднююночьвместес и, думаю ты справишься :d',
#  'взаимно, фанфик ; з и снять 2 - родители испугались :d',
#  'тогда я спокойна :d',
#  'сегодня были у невролога. там внизу сноска :d',
#  '6к твит для *',
#  'с 1 сентября прийти, увидеть всех и пожрём и по пояс :d',
#  'нееет жизнь-боль, а американцы чтобы послушать песни их только с этой бабы :d',
#  'усядемся с тобой все ближе и ближе. эта неделя была слишком упоротой! такие недели еще поискать надо! всем спасибо *',
#  'я как раз просыпаюсь через час, когда тебя я обниму, другого не хочу :d',
#  'живой марьяны? ахаха чувствую нас училка выгонит, как оргазм :d ddddd',
#  'играю в батлууу :d похоже от болезни у меня все не понимают, как я показывала мартина :d аххахаахха машка очень угарала',
#  'крыски, наверное :d огромные плюшевые головы единорогов нынче не в силах воспринимать все, ты одуреешь :d',
#  'ахаха со светкой :d',
#  'иду после института домой и начала анализа, как самый популярный донхек, так много читателей как у джи и фрэна! ииф ю ноу вот ай мин :d',
#  'вручила всем подарки - чувствую, ты для меня всегда первая 3 *',
#  'пока, потом в автобусе смеялся над нами ночью :d мы ток все купили, жалко, я не смогу, так еще бы её многие такой считают просто баба с огромной пиздиной :d',
#  'мини-им для найл отобрал у тебя с нетерпением *',
#  'уау, в моей ленте по-моему только андрадит :d доброй ночи, детка :d',
#  'я не могу, практикую. :d',
#  'кхм, а потом думаешь, кто снова остался без справки? ну ладно дубль 2 :d',
#  'это как-то странно. над погуглить :d',
#  'помнится в детстве хотела, но я ржу то ахахах, да мама, всем кто сегодня будет модный приговор :-d :-d',
#  'готов, только полистала, и да :d d',
#  'на второй фотке они даже не знаю, знаю, что мне :d',
#  'сейчас за телефоном поедим :d не судьба, это потому, что я сейчас того уже не веришь себе :d',
#  'ты не мужик и не говори, что ей изменил мальчик!! диана козявка ^ _ ^',
#  'лооох, меня аж мурашки по всему, у нас хоть женская, а ты где живешь?',
#  'завтра гулять, папа отобрал телефон и завтра др школы :d d #сынывоина',
#  'ооочень круто в театр и в каком ты городе живёшь? о. о выздоравливааай <3 3 ты наверное дофига умный, либо немного плохо :d',
#  'я сказал что у тебя! помнишь? :d',
#  'апзща ну да вольхин, а от физ - ры меня освобождение :d может вы под конец дня поржали с ним сидел тренер и я смотрю сериалы по телеку щас показывают наркоманкий мультик :d',
#  'сфоткала пока он спит. люблю вас *',
#  'ну ладно ладно есть один бомж, хороший или плохой, желающий обосрать всегда найдется :-d',
#  '#klainepocalypse хотя бы за мертвецами :d',
#  'я бы, как мы пели :d в шк всех достала песней про ноги, дак я пришла в себя что ли? са так уморительно падает в эндинге seiken no blacksmith. ^ _ ^',
#  'ты психолог? — путин :d',
#  'но мне казалось, что? :d',
#  'она теперь не лёша... она - мой парень называет меня сосиской :d',
#  'начнем с того дня, а ирина шапками кидается :d',
#  'ведь с этой жопы вылез, дай пять :d и угарает сучка',
#  'пусть у тебя есть! счастлива ^ _ ^',
#  'короче, мама так посмотрела на меня :d',
#  'хм. только декабрь, а не нравится :d просто хотела немного подъебать :d',
#  'мы с катей в маршрутке с еами болтают какие то парни закидали тешку яйцами :d',
#  'кристина ретвитет уже твиты про мужиков и всё тебе можно! у него как могу, умею, но доплел. она ито расписание делает :d',
#  'юольше всего в эти выходные длились так долго ждала :d не против но если развернуться и пойти ещё с детства, с пистолетом, еееах :d',
#  'надо будет очинь хорошо за тобой слежу. :d',
#  'ахахаха нооо примирение то какое привалило я твой брат. всегда. ломаю стереотипы :d d настоящия угроза!',
#  'хотела сделать вид, что он орёт на собаку мама орёт на собаку :d',
#  'если что, сынок, или я читаю слишком много говорю о еде - найл / сказал человек который говорит иногда тааакую ерунду, что чттаешь меня 33 лу тибе 3 *',
#  'я в неё влюбился во сне не кушали, договорился вчера вечером её звали какието бабульки пойти в квартиру. мои соседи определенно меня ненавидят уже :d',
#  'хахахаха максима галкина бросила его любимая :d сижу, мама вообще сказала раз ты ничего не купили то скажу что за хню я несу аахахахахха вадим не спал :d',
#  'а после допов мы с впадиной просрали 11.12. 2013',
#  'ааххаах, все не общаются со мной хочешь? брат нет. нет что вы доктор, но у меня обе :d',
#  'с балкона. там атмосфера своя, другая ^ _ ^ или перекачаю на телефон, подключайся :d',
#  'и еще раз поздравляю * *',
#  'так я и не написал? может подкfтывает? или учеба?',
#  'спасибо тебе, мой мозг :d dd',
#  'аха сейчас видил как мужик едет и бреется за рулем? ктооо? :d #настроение #поднялось',
#  'капец, что мне делать с такими глазами не представляю как... времени нет совсем. *',
#  'мне сказали что я решил неправильно :d ибо разве что если что :d',
#  'jу него ещё появилась парачка новых приколюх :d парень то красавчик, подсказал мне развести кое кого на кое что выбрала, но прекрати обвинять меня в этот раз всем за 70 :d',
#  'ахахха съемки видео уроков от алены :d мы сможем пойти в церковь пойдешь? :d — ахахаха бл да мне тож поднадоело чот... ты серьезно? :d',
#  'если ты выйдешь замуж и будешь жить в лондон на нг приеду :d',
#  'прасци * у меня будет. :d',
#  'кто там посылает мне удачу, но я всегда буду помнить что делать с такими глазами не представляю ленту без нее никак :d',
#  'фаллавь миня, я итак про локи пишу, но всё равно мысли про тебя :d p. s. а вот и я до сих пор отойти не могу :d d ебнутые люди :d вот это новость, вот мы с ним у меня похоже на то тебе и всего, вышел и мы высказали друг другу :d',
#  'завтра мелкому 2 года :d',
#  'интересно, оно старинное :d * __ *',
#  'это лучший поворот событий к вечеру полностью украсили дом. ари тихо зашла в детскую. стояла и смотрела на него потому что меня ударил рузик :d',
#  'опять творческий беспорядок :d вдохновение прёт :d я вот к гиа примерно так я еще в церковь когда нибудь говорил, как ни странно :d',
#  'как же люблю тебя * *',
#  'надо что-нибудь с лошадью, год змеи, стрелец. я вот читаю ленту и геометрию рисую :d',
#  'хочешь сладких апельсинов?? о_о иии * #mtvstars 30 seconds to mars',
#  ':d вот ты смотришь на меня. мне нужен ты и так кривой средний, и у лизы :d :d #коенмилашка',
#  'а у вас не убили :d но я чувствую себя героем :d',
#  'ленинград – без тебя всю ночь. поэтому то и дело что даже на целую книгу хватит :d',
#  'не ну а что случилось? - может сразу?',
#  'да да мнк интересно, что сделала из тупой умною, прости',
#  'как? :d d честно говоря, искусай меня силы не жалей, дурака валяй.',
#  'не забуду наш брак :d и лови ванди 3',
#  'это охуенное чувство, когда тренер накасячил, когда все их видео пересматриваю с этого :d',
#  'мне всегда! :d',
#  'ну и юбки у нас один :d d',
#  'о, круто. после обеда - спать. спокойной ночи малыши мама подпевала песенке из заставки :d',
#  'вот знаешь.. я свои уже просрала и теперь будет твиттер :d м -',
#  'я глеб. по лыбе и выражению лица. / / если есть шанс завтра! и фату!! :d',
#  'аахаха я однажды лёг в 11 часов ко мне, успокойся, сладенький мой пончик *',
#  'я умею тебя веселить, моя золотую девочку, которая пропитана кремом! а я дома лучше :d #bangabanga',
#  'этот момент в #everybodyhateschris - а он купил эти шорты :d',
#  'мне друг показывал и учитель, но знаешь что они выйграют еще в ноябре начинается, начинааается! твиттер улыбается, распылившись на молекулы * :d спасибо с ;',
#  'крч, ванди обязаны победить. сломали vevo. сломали youtube. так я тебя тожеее, ааа * *',
#  'классно потанцевали сегодня с его классом :d',
#  'курящие школьники в новосибирске фитолампы для рассады. у меня возник вопрос а если я серьезна написала? :d d',
#  'ну вот и влетело',
#  'вынесла котенка на улицу бить ковер палкой :d',
#  'я лах написал а потом смешай и о тебе ахах',
#  'только 11 б может петь гимн рф в день феста я вышла из первой, потому что ты по 1 фотки в неделю, какую не взять в пример :d',
#  'и второй не приятный момент, когда будем скидываться на нг загадать :d',
#  'а я два месяца до др с',
#  'я так кричала, когда сестра джуд умирала т. д., на жанночку мою наорала :d',
#  'привет, мой хорооший * и по этому иди обниму :d',
#  'сходили на коток... хороший мой, был лучше :d',
#  'зато он в кадре :d',
#  'а что случилось :d',
#  'ты уже большая! желаю сохранить пофигизм на весь мир = * * обнимаю монитор *',
#  '- нас нельзя закрывать в четвером в четырех стенах, а то блин важную новость в 6 утра написала :d',
#  'эм я высказала ему все карты открывать ахах',
#  'давааай.. и верю. завтра продолжение, может и могу, даже не обидно. привычное дело.',
#  'растегнутая рубашка колфер вырос и уже все стены обтирает',
#  'утречка * * * * азааз чукрк * ахахах :d',
#  'сижу уже несколько месяцев ждёт, а кончик :d ахаха а вообще может быть феил :d',
#  'я заказала книг на 2000 рублей :d cук они сломались но микрофон работает я - только музыку не включай. -. о марсик, спасибо * ты будешь говорить друзья, и в розовых носках... идеально! :d официально провозглашаю вас добряшкой-няшкой, сеньеро! #снкрс #дбрта',
#  'если бы в школу прись!! мяяу *',
#  'как они до меня и орут. моим ушам больно!',
#  'ох, блин :d как ты избугалазь :d',
#  'да. хотя.. :d',
#  'не только в выходные или поздно сводится к отелю :-d так что то классное тебе сделать выбор? я ужасно скучаю... я хочу, чтобы пойти гулять вечером, нуну, я как-то вмешиваться не хотел его есть, но не забываем про то, он не слишком залипал на старка :d',
#  'возможно, у меня смотри сказала! :d',
#  'оуууи, это было круто, хорошо ли это, когда есть супер смешные записи в группе у ирины дмитривны и в мою ленту это бы вписалось почти незаметно :d dd',
#  'реплики? ну-ка рассказывай :d я ж хитрый жук :d пошла смотреть молодежку аеее.',
#  'нет ну я пока так общаюсь :d',
#  'не забудьте в пять часов учил и не навыебываться на какую тему сочинение? *',
#  'он поёт для тебя это меньше выражено :d ddd',
#  'воувоу у меня музыкалка после школы 33 опять в месте я с речицы. это я сегодня первый раз :d',
#  'почему так?.. сейчас бы рядом тебя * не сдержусяяя',
#  'играть в симс. пока извинялась за твиты на геометрии :d',
#  'я хоть и мало, мало ли она? мы с ребятами так заболтались, что у фёдора большой опыт в этом году :d',
#  'да, я бомж и нищеброд :d',
#  'кхм, я тоже просто глупый поэтому.. мы бы устроили настоящий пати хард! :d',
#  'утро... выходной... теплая постелька... твиттер... вот крисусе при своей брутальности плюшевую живность одобряэ :-d',
#  'и тут я поняла, то не безобразно :d хотя она худая',
#  'ахаха, нет, но завтра иду в школу! мне google смс прислал :d',
#  'пфф. моя маман стоматолог :d нельзя у меня институт :d',
#  '6 декабря-день лентяя, то не стыдись :d логичная ты моя последняя надежда! - не нравится мне этот отчаянно проскальзывающий намёк :d',
#  'девушки старшеклассников :d ахах, он хочет, чтобы я кинула :d',
#  'если бы не унесла :d',
#  'хахах, я те ни дам, ихихих #тыменяспоитьхочишь? :d - ок, тогда я тебе только фото показала, как будто я сейчас сделаю так, решил что я идиот, только не очень с голова болит т. д вот и произошло моё первое зимнее подение... с',
#  'я не отрицая это.. я уже в универ',
#  'если всё пойдёт как надо прогуливать пары :d',
#  'да музыку слушаю... ^ _ ^ сукапздц',
#  'никто торт не хочет меня выпускать, шипит и бросается на меня, понял, но не могу :d странная хуйня.',
#  'что не замечаешь, я буду называть ваньку сусленком * * безумно ее люблю ♥',
#  'да отстань, у нас своя атмосфера *',
#  'воу, барышня! я подкинул тебе ведьменский мешочек, теперь знаю подробности про классы :d',
#  'я обожаю пэна :d ахаха витя они сто пудого забыли что это такое место, где у тебя сейчас добавлю в беседу',
#  'вот такой классный физик попался... - да, девушки сейчас вот читали до слез :d',
#  'козерог. 13 я заключила контракт о моем бракосочетании через 8 лет, что я может быть, не смей умирать фиона! :d',
#  'как я рисовала у алины плокат на день рождения у моего бро кличка ёжик, я победитель по жизни :d dd',
#  'спасибо тебе любимая за то, тому достаётся весь скрипучий снег ^ _ ^',
#  'зашла вчера на спрашивай, а как я ему еще план съемочной площадки нарисую с расстановкой в камере :d',
#  'если быстро переключать, то я счас ухожу',
#  'я не знаю какого цвета у тебя верные мысли, го',
#  'маленькая девочка замечталась, а для носа нет * беда сс молодец, а может в таком состоянии :d',
#  'я думала, тут уж твое решение *',
#  'ахахахаххах :d вот не люблю йовович, но полны энтузиазма! :d',
#  'я ж могу себе позволить написать :d',
#  'даша, всн из за больного горла. но мы нашли решение прикрыв сумками голову :d',
#  'да да, знаю. пол тебя пиздит, а потом ты меня раздразнила? :d d',
#  'ахаах, клас, а ты пьян :d',
#  'ручная лошадь. теперь она мне - только у 4 самых близких людей есть подбородок :d',
#  'снуп в одноклассниках? зато в игру играла :d dd',
#  'у меня сто гигов спанч боба и самый вкусный чай. втрое утро подряд, если это утро с сартисян началось :d',
#  'у меня были наушники и в моих руках китайские палочки превращаются в барабанные и всё, они мусипусички которые любят обнимашки <3 вчем ложек! cha 3e поймут :d …',
#  'вот так выглядит.',
# ...
#  'почему, но все ровно просрешь :d',
#  'опять пеле в караоке всяких лок догов и дим биланов, типо кормилица :d',
#  'ахахахаххаха, и с подарком',
#  '12 :d его светка так назвала :d так что - то :d dd и часто у типя вапщи нет ни одного читателя, а то она тогда себя как лугуев. все. мой любимый твиттерский ; з моя - омг, и думала над проектом :d',
#  'единственная фотка тейлор, которая видит дату смерти любого человека, даже владик так не кипишуй :d йоу',
#  '#happybirhdaytrecoolfromrussia #happybirhdaytrecool :d с него убрала :d',
#  'так забивай, шож ты моментом то не успеваю, а то скучно как то странно мне :d особенно на вопросе о сумерках, когда катались на роликах, а то я бомж и нищеброд :d',
#  'я тоже когда первый кончился можно и не в 6 буду *',
#  'оолимпиада по истории 5 схватила, до, я просто рада, что тебе понравилось *',
#  'а музыка из сериала мне очень нравится этот юн, я спасу тебя :d да',
#  'это ванильно в такой магазин с а ты не позволишь своим людям ничего со мной сидит!! :d',
#  'обьявляю время ночного жорства открытым, т. п, но читая ленту, а теперь мой вчерашний чертеж!!!',
#  'итак. никогда не видела как мы с макаровой вот в туалете закрывал :d',
#  'тебя суп волнует больше всего * чайчайчайчай з',
#  'ну да, мегафон, я жду тебя с лешей лазаревым? — нивидимкааа :-d :-d :-d :-d',
#  'воу я прошёл тест на агрессивность :d мы вис сдавали а я между прочим, когда меня начинает таращить. я хожу в церковь когда нибудь?',
#  'это сексицикл, детка, а то я не устану это говорить прямо в зале, все начали говорить о возникновении жизни на земле среди нелогичных людишек и сам же ее съесть с андрей такой андрей :d',
#  ', почему ты такой добрый 33',
#  'быть студентом? это реклама меня бесит :d',
#  'открыла тане аудиозаписи... там.. ну блин, этот звук поменял моё сознание... это злость лизыы!! большое спасибо всем кто мало ест и плохо спит, он и на столе уже порядок навели :d кто же ещё',
#  'вот такую хрень я делаю рт :d почему бы и да, я замечала уже это и есть :d',
#  'а раньше я была в куртке и шапке, ахаха :d',
#  'открытой урок по лит-ре - это хорошо, что пора домой :d #rad …',
#  'это мой милый :d',
#  'я по себя, в водичке барахтаться :d',
#  'утром не было 20 минут * *',
#  'как прияяятно * спасибо за то, что я этого в ленту срёшь только ты, машина и радио :d',
#  'все для моего неизбалования :d',
#  'я пикап мастер украины :d',
#  'милыыый, да найлуш тоже у гарри телефон на хореографии. увидела вот это неожиданность, вот и поговорили :d #сериальныйзадрот',
#  'короч сегодня еще у меня горло болит с *',
#  'алиюшкам, мин сине нык-нык сагындым. ты могла? с',
#  'ха! я еще не целовал :d',
#  'почитала вашу переписку с начала декабря думаю что хорошо что я сегодня когда узнал об этом думаю, что навсегда остается в этом есть :d',
#  'ахах да норм, менеджерам пизда :d dd',
#  'человек прошел ядерную войну, освоил космос и прочеее, а потом умирать со смеху хд',
#  'сарказ так и сделала ✌ ️',
#  'так его любила и не стирал бы :d ахахаха ее выражение лица фила :d d — пффф, считалка нам в вк есть графити :d ddd',
#  'упоролась с в ништо просто!! :d dddd',
#  '2 раза проспала, 1 девочка ей можно',
#  'сейчас вполне с серьезным лицом я начал читать он немного под марихуаной :d',
#  'знал бы он сделал киёми? :d да, просто это не стоила, твоя тайна раскрыта :d',
#  'ахахах, а вы леди? ахаха посмотрим потом оценку :d',
#  'хэй, да, к которому я так привязалась з хоть и баян :d настроение отличное',
#  'хочю побыстрее увидить свою подругуу! я очень умная собака. :d d шутки она тут шутит',
#  'прогууульщица :d я в школу не накрашенная :d дома делать надо было мне меньше на фитнесе ржать с этого момента буду гордиться этим! :d',
#  'это в тви, то будет кровавое месиво, ахха :d',
#  'я фандомная куртизанка с что по утрам!! :d ddd',
#  'целый день с gta sa вышла на ios … вот и условия! :d',
#  'ребята, вы, сцучки эксо, стойте, все в классе? :d',
#  'збс весело время провели :d теперь понимаю, но он тоже репер в топдог :d',
#  'я научную работу защищал, лал. кстате, у кого кроме филатовой не видела',
#  'но нужно голосовать!!! безумно не хватает тебя * * *',
#  '- пока - пока о я чо то забыла :d',
#  'нафиг конец света :d d',
#  'а похуй, на счет положила не она, а в музыку. какой же замечательный день!! мы с впадиной просрали 11.12. 13 12:13 12 те, у меня есть :d',
#  'ну и трудный у тебя андроид, не люблю его :d',
#  'вчерашния фотка, то поможет коньячок, коньячок, коньячок, коньячок, коньячок :d',
#  'у моей девочки день рождения * я в травку я тебе секрет расскажу? я ищу по крайней мере точно первым :d',
#  'у нас есть тот, кто отец :d',
#  'бен отвлёк мартина звонком отца, а он норм? :d я не режу вены :d',
#  'этой моды, я от этого не одобрил :d',
#  'надо будет касплеить своих кумиров, а потом уже проси о сердечке :d d всем мармеладностей 3',
#  'мои любимые, спасибо * и да, они меня домой где-то час отвозили, хотя стоим рядом хд',
#  '/ 15 ^ /.. / #followback',
#  'в общем, на ватрухе :d а может не из-за тебя * персональный гарри с а мне еще голову сушить удачи тебе и счастья :d',
#  '#хочупровестиновогоднююночьвместес о, я прекрасно помню, теперь где можно найти аню? на кадышеву или укупника? :d',
#  'а похуй, на физру пожалуй не пойду, малыш, только полистала, поржала, при свете от ноутбука развешиваю гирлянды ^ _ ^',
#  'ахахах, голубкиии.. это что-то новенькое :d',
#  'иногда мне это скинуть :d',
#  'нужно взять фотик на электив, а там нет ограничения по символам, к вам! :d',
#  'впервые за долгое время я была в восторге от твоей работы :d',
#  'кто поведал тебе этот великолепный способ?! я давно его не понимаете машинка будет такая что ваша челюсть пойдёт погуляет на соседней улице :d',
#  'и тогда все норма :d и не умею :d',
#  'вы это вполне нормальное явление в моей тусе нет мышей, потому что ты купишь в первую очередь делаю самым близким друзьям, а вторая фотка как будто вы не дружили месяц о',
#  'даже мой учебник по биологии и диагностическую работу по алгебре 0,0, 1,1, 2,2, 2,2 и 4 человека едут на автобусе :d я тебе писал, и интересный. крч. заранее спокойной ночи. особенно с какой стороны ни подойди, везде! у меня таких знакомых нет. — собираю марки :d',
#  '9 из 20 :d так не тащилась. это уже реально смешно :d',
#  'первый раз :d d',
#  'было бы не моя шапка, он бы создал только колобков... :d ddd',
#  'надеюсь ты уже спрашивала, где ты так и сижу ржу с фоток exo xd ещё и 2 моих любимых он самый маленький 3 и желаю ещё больше счастья, здоровья тебе ну и ненавижу, когда он пишет в твоей тетрадке, когда в россии все такие на диету сесть :d',
#  'офигенный концерт мама у меня нет такого предмета даже нет с только в конце просто не давно погуляли, накормили друг друга с переписываемся в твиттере и вк одновременно :d',
#  '#happybirthdaytrecool с днём рождения * ты тут заливаааешь? :d',
#  'и такое бывает :d мне больше ничего интересного. разве что у них такое настроение',
#  'спаренный урок с 7к, алинка « чувствую себя дедом морозом ^ _ ^',
#  'тьфу. конечно! это хорошая штука!! спасибо. и всё время думаю и верю. завтра жду законную половину *',
#  'оказывается у нас оч классная школа :d dd',
#  'как ты там устроилась :d я тебе обязательно скажу 3 мне уже даже имена их знаю :d у',
#  'ахаха, очень.. * прикрыла глаза. мне очень нравится > ^ _ ^',
#  'ну тогда заебись, я и так великолепна... — никто не видит. а так тожи уральская бабонька ахзахаз :d',
#  'как ни странно это не я',
#  'конечно есть :d и все равно мне делать скажешь? :d #тануки',
#  'мелкие боялись старшеклассников, а я еще кому то интересен * * *',
#  'а кгда суслик вышел че дальше было ты помнишь в каком городе? хах, хорошая моя *',
#  'спасибо тебе! * * ещё и дёсна себе разорвала :d',
#  'о да, я обычно ставлю на две гонки подряд, так привязался к *',
#  'ох, 900 :d ну спасибо :d',
#  'мне нравится когда куроко с тем, что дост с драйзером разговаривают :d - в лондоне. там пейзаж по лучше будет * я люблю тебя, аххахх, опять стебать начинает, ррр. за то, что у него активная пере-писка! :-d compad, батяня, батяня, compad, батяня, батяня, батяня, compad, вези ж меня знаешь я без тебя всю ночь на роликах, а тут взяла тетради, стерки, линейки, и даже в каком-то сериале снимался, нет! - сиськи - самое главное не ста …',
#  'на кого :d правда пока не выгнули :d',
#  'ахахахах, алин, к вам хотела <3. привет, докта 3 тебе повезло :d',
#  'настя правильный вопрос мы курили его 2 часа, кароч :d',
#  'ну ладно, пойду поем :d',
#  'ей нужны только dior, gucci, manolo blahnik, а сейчас - у меня тут свои портреты :d',
#  'моё др через 3 месяца недотрах :d такой интересный вопрос ;d',
#  '- помнишь ты в моей ленте! >:d и пару видео. и ты с кочетовым в одном теле, бич! сукааа радости нет предела *',
#  'терь понятно чем кайки в том то и слушаю меня, я тащусь с того, как я наливала чай :d',
#  'надевай. но я вчера из ленты рано ушёл',
#  '#kulapipundrium не работает вк, инсто и суда тви! ждите!!!!! всех с праздником красвого числа 11.12. 13 12:13 да ну :d он уже два поклонника стивена кинга читают, лол. я сейчас в твоем доме :d только ты * *',
#  'у моих друзей и без президента ахахах',
#  'мы будем каждый час, ох щиеть. два с половиной часа :d нуда кто опять не выспится? :/ я тоже щас бы к вам хотела <3. привет 2 - ой паре, ахаха',
#  'это лучший поворот событий к вечеру! я всей душой.. поделился своим несчастьем.. эх вы! :d',
#  'яриман - шлюха!!! :d',
#  'эх уже месяц, новые даты и пр. :d',
#  'пришли в кафе. ждем заказ уже полчаса ухожу из vk то фики-обложки обсудить, то обязательно буду настаивать о встрече с человечком, и ты дальше знаешь :d',
#  'ахахахахахаахах нееет :d #echelonlovesfathers',
#  'как залечить душевные раны? — ахахах, жениись :d d',
#  'ты просто космос, когда вся окрестная школота и студентота начинает с 1 марта полиция сможет закрыть любой веб-сайт без суда смешно :d',
#  'у меня 9 номер на форме, пока мой идеальный макияж :d',
#  'люблю тебя!!! :d d пугаем, ржем, весело было, а мне еще и с бутылкой какого-нибудь хорошего напитка, да и вообще мне все напоминать. спасибо, вам пакет надо? пускай идут лесом :d',
#  'в вк найдешь, я постараюсь все подобрать :d d',
#  'ахахахах хитрый сука ты такая милая.',
#  'моя лента взорвется, когда находятся рядом :d dd',
#  'ммм, я только сейчас :d',
#  'ващето от менч до уручья 4 станции метро :d ахаха витя они сто пудого забыли что это будет... вменяемые оценки :d',
#  'короче пойду дом 2 смотреть, приходится смотреть дашу путешественницу. :d',
#  'сочинил офигенный соляк чтобы во время рекламы выпила у меня проблемы с тем чуваком woooork faaasteeeerrr! :d',
#  'это сабберы так прикололись или реально там про такое было в иркутске, подружка товарища дала ему номер дозв',
#  'реебят перескажите мне кратко рассказ тарас буульба пажалки мне так лень, приходи к ней, приложу пальцы к переносице, и запомнила :d',
#  'да пусть всё дело в магнитном поле :d',
#  'инженерка мне настроение *',
#  'дохуделась до такого, что ли? :d',
#  'пришла маша в новогодних носках. лягуха :d :d',
#  'моя сумка еще хуже, наша команда низкая. двоешница? :d — тебе показалось 3',
#  'от від одного слова, а в говно. >:d',
#  'давно так с первого дня стоит, и позвонила в 6, чтобы мы сшили ей в кабинку снег :d ddd',
#  'будь менее назойливее, друг друга 3 обожаю его * *',
#  'а этот статус я посвящаю своей первой любви! * у меня 16:11 :d',
#  'спасибо, дорогая? *',
#  '2 место в чире и в исполнении сэма, тины и блейна? это норма :d я уже с несколькими такими поругалась :d',
#  'лол я на стихи. ру, хватит, мне больше не выйду, увидимся весной :d',
#  'за мной вечно этот грешок :d забываю отвечать на экзаменах. ” :d dd #hg #katniss',
#  '- хорошего человека от плохого? — dzeršana :d',
#  'спасибо моя * уже хочу хочу хочу * * поздравляю тебя, безумно скучаю за тобой следить :d',
#  'посмотрела бы я не хочу стареть :d',
#  'я не думаю что хорошо что у фёдора большой опыт в этом смысле :d d',
#  'в предвкушении вечера сinema cafe жди нас * * *',
#  'та, ты у меня полтора дня, как алина надо мноой, вахахахаха :d',
#  'зайчику маленькому сегодня полгода * мой любимый * я тебя с миша коллинз и бенедиктушка :d',
#  'а это мой дядя и 2 моих любимых он самый маленький 3 и я довольно живуч. короче хуй меня убъешь :d',
#  'м тебе точно много будет, не хочешь попробовать? — мороженое :d',
#  'завтра пятница 13? ой, да тебя заложили по полной программе :d и не заставили идти трясти ковер :d хоть географию по …',
#  'нет? окей? :d dd заебала смешить уже :d',
#  'блин, печальнр конечно. это последняя фотка из школы притопал не давно придумал, и возвращайся к нам с катей дружить начали :d',
#  'утречка * * спасибо за песенку ^ ^ остальные сосайте :d #мастерфш80лвл #нуашто #люблюдусю',
#  'ахахахаа кого вырежешь? френка? или вообще не понимаю :d все равно самые лучшие мои :*: * *',
#  'саша, мой принц :d',
#  'сегодня кр писали по алгебере-хуялгебре потом как труп ходил по городу. наблюдал. пожалуй, это синхронизация хреново пашет просто на самом деле я парень, но могли бы что-нибудь поинформативнее снять :d',
#  'узнал результаты межвузовской. решено 4 задачи, но не выходит... :d',
#  'семья-самое дорогое что может быть заживление :d',
#  'ахуенно сходили в душ пошла, меня саму эта уборка задолбала',
#  'азаз, ну хоть всякой фигни не скажет! :d',
#  'ты должен выглядеть, как я хорошо пою апхахаха x-factor жди меня :d dd',
#  'я вот практически постоянно с телефона и без пошлостей никуда :d',
#  'я заплатил за это з',
#  'таак, номера домашние вы знаете, иногда я нравлюсь себе :d',
#  'крёстную, илюшу василюка и его и расскажу :d',
#  'с ушлепком по скайпу :-d :-d :-d :-d спасибо стеепаш :-d :-d :-d :-d',
#  'пока сегодня сидела на той скамейке, там так и подумала красиво сжечь её :d но мегафон точно в ан. с днем рождения тебя * / муааа',
#  'если вы не доверяете вашим мужикам никак не сяду за дз. а посмотреть где и как помогло? - даррен крисс такой жестокий, мать твою, кэтрин пирс мне в художке было так мило',
#  'не, ладно :d раз не задумываешься о хорошей порке :d',
#  'обоже я ржу как дибил :d ddсделал вид что не 2 :d',
#  'чтооо? по какому предмету доклад? о. о внезапности. ладно :d раз не удалось сегодня перенести сайт — сделаю для него * #гшпоймет :d',
#  'надо, но не могу, я тя обожаю, когда ты чувствуешь :d',
#  'люблю людмилу михайловну. я посмотрела промо новой серии :d',
#  'диму, видимо, никто бы не проведешь в шк весело, и залейте в твиттер, вот горло полоскаю клиенты же не варвары, чтобы ответить темы по литературе много задали, лень делать',
#  'только сел я готовится, и один дома не дойдёшь обкидают по реале :d dd',
#  'любим петь в караоке всяких лок догов и дим биланов, типо у меня шарф локо отжать пытались :d',
#  'тебя тоже отомщу :d на айфон, чтобы я шла в детстве прилипала языком на морозе. к. первое не получилось :d',
#  'смотрю сезон охоты и тут каждый узнал себя :d',
#  'даррен, ты просто идеал для меня это сделать :d',
#  'а снегурочка так бодрит ахахахаха, тогда, я забыл кто я с ним связано? :-d',
#  'а что случилось? если универ закроют, то значит ты победишь *',
#  'ахахахахах даа, долго еще с ними связано. тебе как обычно и бывает, кстати :d',
#  'нереально люблю свой класс :d.',
#  'ага, а ты как хоть? :d',
#  'хочется анфолловить половину ленты, которая тип эшелон :d ну как же я буду жить :d',
#  'а во втором, мне захотелось порнухи... а у тебя даже не слышал что телефон себе новый хочешь? :d',
#  'хе-хе-хе-хе... радуга, значит наше х место - кровать',
#  'сейчас посмотрю заявку... вдруг я его пока не понравится? :d',
#  'спать сильно хотела. зато срать на тяжесть запросов :-d',
#  'руслана сказала, чем видел. но не надо, ибо у меня на водолазке :d а я сегодня без тебя всю ночь на роликах, а на руке. ощущение такое, как бы намёк :d #bap #himchan',
#  'ахах и спала, я успела уже поспать - лана здесь, до спортзала дойду :d',
#  'этой зимой я буду дома краситься',
#  'меня уже второй по счету какой урок? - ляльку ищет :d',
#  'не волнуйся, все просто блингеровские замашки :d',
#  'со мной её слушают ещё 3 письма осталось написать и отправить, так идет им форма, аж самому понравилось, вчера кто то получит пиздюлей :d',
#  'ибо нехер ему с юлей просрали весь рабочий день, куча фоток и видео в инсте уже две фотки новые :d',
#  'а я смотрю мультик з',
#  'сука :-d ну бля, да :d апхзаппхихихих',
#  'он никогда не замечала еще, мы почти полным составом :d',
#  ...]

# %%
def scale_prob(prob):
    return prob * 2 - 1

# %%
df_all = pd.DataFrame(generated_all, columns=['text'])
df_all.sample(5)
# Out:
#                                                    text
# 8166  стоп. я совсем забыла, что с твиттером что-то ...
# 4864  11.12. 13 14:15 загадала желание, поставлю буд...
# 583   как новый год я встречаю со скайпом, как будто...
# 7282  о боже! как ты живут долго :d я думаю что можн...
# 4456  никогдааа, останусь сумасшедшим. буду скучать ...

# %%
# %%time

df_all['sentiment'] = df_all['text'].apply(lambda x: scale_prob(grid.predict_proba([x])[0][1]))
# Out:
# Wall time: 48.8 s

# %%
df_all['sentiment'].hist()

# %%
df_positive = pd.DataFrame(generated_positive, columns=['text'])
df_positive.sample(5)
# Out:
#                                                    text
# 5795       ахах. девушки, кому интересно то суда - :d d
# 4327  вот нифига :d вот так надо учиться нормально.....
# 1030  внутренний сдала, осталось еще пережить один з...
# 3000                             всем так интересно! :d
# 3061  долго ехать в фото-школу, но как хорош родной ...

# %%
# %%time

df_positive['sentiment'] = df_positive['text'].apply(lambda x: scale_prob(grid.predict_proba([x])[0][1]))
# Out:
# Wall time: 48 s

# %%
df_positive['sentiment'].hist()

# %%
df_negative = pd.DataFrame(generated_negative, columns=['text'])
df_negative.sample(5)
# Out:
#                                                    text
# 4997  мне очень долго попадались фото, где ты живешь...
# 3409  о_о ну хилла точно не ожидала такого о_о интер...
# 6061  хмм, не один, пьющий кровь младенцев, кажется ...
# 4082  это далеко не норма о_о у кого-нибудь есть мег...
# 191    блять :| я тебе сейчас в недвижку уже невыгодно.

# %%
# %%time

df_negative['sentiment'] = df_negative['text'].apply(lambda x: scale_prob(grid.predict_proba([x])[0][1]))
# Out:
# Wall time: 48.9 s

# %%
df_negative['sentiment'].hist()

# %%
print(len(df_positive), len(df_negative))
df_positive_negative = pd.concat([df_positive, df_negative], ignore_index=True)
df_positive_negative
# Out:
# 10000 9997
#                                                     text  sentiment
# 0      у нас тоже задротят, правда иногда бывают прип...   0.999991
# 1       типичный каравай :d спасибо большое, девочки? :d   1.000000
# 2                       лучший день за последние годы :d   0.999883
# 3      вот любишь одного. встречаешься с другим. и т....   0.957186
# 4                    это как на своей летающей машине :d   1.000000
# ...                                                  ...        ...
# 19992  я почему-то думала, что я не хочу его провожат...  -0.175935
# 19993  нихера о_о спасибо за то, что это так напрягае...  -0.891832
# 19994  бли так хуево вышли я ж забыл тебя поздравить,...  -0.284198
# 19995  ненавижу такие ситуации, где они в полосочку. ...  -0.193028
# 19996          найл рок ме гарри меня штырит зейн о,,,,,  -0.219389
#
# [19997 rows x 2 columns]

# %%
df_positive_negative['sentiment'].hist()
